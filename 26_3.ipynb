# %% [markdown]
# # Creating an ML algorithm from scratch by Numpy

# %%
import numpy as np

import matplotlib.pyplot as plt

from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# # Generate random input data

# %%
observations = 1000
 
xs = np.random.uniform(low=-10, high=10, size=(observations,1))
zs = np.random.uniform  (-10, 10, (observations,1))
 
inputs = np.column_stack((xs,zs))
 
print (inputs)
print(inputs.shape)
print(xs.shape)
type(xs)
# Out:
# [[ 6.6938605  -3.79570796]
#  [-9.87582629 -1.12912477]
#  [ 7.15431211 -8.34170201]
#  ...
#  [ 0.52977957  8.82907972]
#  [-6.52886774 -3.42880184]
#  [-4.63152619  9.31777084]]
# (1000, 2)
# (1000, 1)
# numpy.ndarray

# %% [markdown]
# #Generate the targets
# Targets = $4x-5z+9$ + noise

# %%
noise = np.random.uniform(-1, 1, (observations,1))
 
targets = 4*xs - 5*zs + 9 + noise
 
print(targets.shape)
print(targets.ndim)
print(targets.size)
type(targets)
# Out:
# (1000, 1)
# 2
# 1000
# numpy.ndarray

# %% [markdown]
# #Plot the targets and training data
# ### Before procceding further, let's show you something about `ndarray (n-dimensional array)` in NumPy!

# %% [markdown]
# ![numpy_arrays-1024x572.png](data:image/png;base64,...)

# %%
targets = targets.reshape(observations,)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
 
ax.plot(xs, zs, targets)
 
ax.set_xlabel('xs')
ax.set_ylabel('zs')
ax.set_zlabel('Targets')
 
ax.view_init(azim=100)
 
plt.show()

# %%
targets = targets.reshape(observations, 1)

# %% [markdown]
# ### Initialize variables

# %%
init_range = 0.1

weights = np.random.uniform(low=-init_range, high=init_range, size=(2, 1))

biases = np.random.uniform(low=-init_range, high=init_range, size=1)

print (weights)
print (biases)
# Out:
# [[-0.01072326]
#  [-0.00375892]]
# [0.03949629]

# %% [markdown]
# #Set a learning rate

# %%
learning_rate = 0.02

# %% [markdown]
# # Train the model

# %%
for i in range (100):
    
    outputs = np.dot(inputs, weights) + biases

    deltas = outputs - targets
        
    loss = np.sum(deltas ** 2) / 2 / observations 
    
    print (loss)
    
    deltas_scaled = deltas / observations
    
    weights = weights - learning_rate * np.dot(inputs.T,deltas_scaled)
    biases = biases - learning_rate * np.sum(deltas_scaled)
# Out:
# 726.7598757791093
# 117.70357325537445
# 46.381257940997365
# 36.6956150379917
# 34.29740764898003
# 32.827467269420055
# 31.519302342884643
# 30.27617147508207
# 29.083981033204438
# 27.93920410541729
# 26.839761124963065
# 25.783830169833855
# 24.76968545726264
# 23.795672854979266
# 22.860204164229994
# 21.9617541030789
# 21.098857758324588
# 20.27010818815194
# 19.474154126848646
# 18.709697781396294
# 17.975492715407853
# 17.270341816824896
# 16.593095346040933
# 15.942649061265534
# 15.31794241807198
# 14.717956840193077
# 14.14171405874542
# 13.588274517174389
# 13.056735839319076
# 12.546231358099403
# 12.055928702426408
# 11.585028440031772
# 11.132762774003568
# 10.698394290903176
# 10.281214758422005
# 9.880543970617664
# 9.495728638846803
# 9.126141326586282
# 8.771179426405823
# 8.430264177424252
# 8.10283972164724
# 7.788372197647828
# 7.486348870112199
# 7.196277293831177
# 6.917684510774618
# 6.650116278939298
# 6.393136331713066
# 6.14632566654771
# ...

# %% [markdown]
# # Print weights and biases and see if we have worked correctly.

# %%
print (weights, biases)
# Out:
# [[ 4.0007885]
#  [-5.0073511]] [7.82433501]

# %% [markdown]
# # Plot last outputs vs targets

# %%
plt.plot(outputs, targets)
 
plt.xlabel('outputs')
plt.ylabel('targets')
plt.show()
